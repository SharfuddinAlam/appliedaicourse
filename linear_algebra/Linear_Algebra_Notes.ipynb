# %% [markdown]
# # Linear Algebra
#
# ### Coordinate Geometry
#
#
#
# **Distance between two points in 2d/3d/Nd**
# * Distance between two points in 2 dimensions
#
# Let $p_1 = (x_1,y_1)$ and $p_2 = (x_2,y_2)$ be two points in cartesian coordinate system. Let d be the straight line/distance between $p_1$ and $p_2$. Then the distance can be calculated as follows
#
# $$d(p_2,p_1)=\sqrt {(x_2-x_1)^2 + (y_2-y_1)^2)}$$
#
# ![scatter_plot_iris](../images/2d_dis.gif)
#
# The above distance is also called as Eucledian norm or Eucledian distance or $L_2$ distance.
#
# * Distance between two points in 3 dimensions
#
# Let $p_1 = (x_1,y_1,z_1)$, $p_2 = (x_2,y_2,z_2)$ be two points in $R^3$. Let d be the straight line distance between $p_1$ and $p_2$. Then the distance can be calculated as follows
#
# $$d(p_2,p_1)=\sqrt {(x_2-x_1)^2 + (y_2-y_1)^2) + (z_2-z_1^2)}$$
#
# * Distance between two points in N dimensions
#
# Let $p = (p_1,p_2,p_3,...,p_n)$, $q = (q_1,q_2,q_3,....,q_n)$ be two points in $R^n$ . Let d be the straight line/distance between $p$ and $q$. Then the distance can be calculated as follows
#
# $$d(p,q)=\sqrt {(p_2-q_1)^2 + (p_2-q_2)^2 + (p_2-q_3)^2 + .... + (p_n-q_n)^2} \ \ =  \sum_{i=1}^n \sqrt {(p_i-q_i)^2} $$
#
# **Equation of Straight Line/Plane/HyperPlane**
#
# * Equation of a straight line in $R^2$: $ y = mx + c$
# ![scatter_plot_iris](../images/eq_2d_line.png)
#
#
# The value $m$ is called slope or gradient of the line. The value $c$ is the y intercept. If $c =0$ then the line passes through origin.
#
#
# Alternate notation, this is also an equation for a straight line $w_1x_1 + w_2x_2 +w_0 =0$, where $y=x_2, m = -\frac {w_1} {w_2}, c = - \frac {w_0} {w_2}$  or, $\sum_{i=1}^2 w_ix_i + w_0 =0$
#
#
# * Equation of a plane $R^3$
#
# In three dimensions we get a plane, $w_1x_1 + w_2x_2 + w_3x_3+w_0 =0$ or, $\sum_{i=1}^3 w_ix_i + w_0 =0$
#
# * Equation of a HyperPlane $R^3$
#
# In $N$ dimensions, it is still a plane but its called hyper plane, $w_1x_1 + w_2x_2 +.....w_nx_n +w_0 =0$ or, $\sum_{i=1}^n w_ix_i + w_0 =0$
#
# * Which dimension doest the intercept $c$ belongs to in higher dimensions?
#
# The constant $c$ is the sum of intercepts across all dimensions
#
# * Intercpet form of equation of a plane
#
# TBD
#
# **Distance of a point from a line**
#
# ![scatter_plot_iris](../images/dist_of_pt_2_line.png)
#
#
# The distance from the point $p(m, n) $ to the line $Ax + By + C = 0$ is given by: $d=\frac {|Am +Bn +C|} {\sqrt {A^2 +B^2}}$
#
# **Equation of Circle/Sphere/HyperSphere**
#
# Eqaution of a circle: $ (x-h)^2 + (y-k)^2 = r^2$, where r is the radius of the circle.
#
# ![scatter_plot_iris](../images/eq_circle.png)
#
# A circle in 3 dimensions becomes a sphere
#
# Equation of a sphere $(x - a)^2 + (y - b)^2 + (z - c)^2 = r^2$, where $(a, b, c)$ represents the center of the sphere, $r$ represents the radius, and $x$, $y$, and $z$ are the coordinates of the points on the surface of the sphere.
#
# A sphere in n-dimensions becomes a HyperSphere
#
# The general equation of a hypersphere is ${x_1}^2 + {x_2}^2 +{x_3}^2 ... +{x_n}^2 = r^2 $.
#
#
# **Equation of Ellipse/Ellipsoid/HyperEllipsoid**
#
#
# * Equation on ellipse in 2-D $ \frac {x_2^2} {a^2} + \frac {x_1^2} {b^2} = 1$
#
# ![scatter_plot_iris](../images/ellipse.png)
#
# * Equation on ellipse in 3-D $ \frac {x_2^2} {a^2} + \frac {x_1^2} {b^2}  + \frac {x_3^2} {c^2} = 1$
#
# * Equation on ellipse in N-D $ \frac {x_2^2} {a_1^2} + \frac {x_1^2} {a_2^2}  + .... + \frac {x_n^2} {a_n^2} = 1$
#
# **Inside/On/Outside**
#
# In classification algos the goal is to seperate classes geometrically. Using the equation of a line/plane/circle etc we can determine if the point lies on the surface, inside or outside the surface. This is useful in class determination.
#
#
# ### Matrices
#
# **Representing data as a matrix**
#
# Typically, data is represented in a table or rows and columns format. The usual notation is $D = \{ x_i,y_i\}^2_{i=n}$, where D is contains features or input variables or independent variables or predictors and y is called labels, output variables or dependent varaibles or responses
#
#
# **Rows**
#
# Rows are observations
#
# $$
#   \begin{pmatrix}
#     x_1 & x_2 & .... &x_d \\
#     .   &  .  .... &.\\
#     x_{n1} & x_{n2} & .... & x_{nd} \\
#   \end{pmatrix}
# $$
#
#
# **Columns**
#
# Features are usally represented as columns
#
#
# **Transpose**
#
# let A = $ \begin{pmatrix} a & b\\ c & d\\ \end{pmatrix} $, then $ A^T = \begin{pmatrix} a & c\\ b & d\\ \end{pmatrix} $
#
# **Determinant**
#
# * let A = $ \begin{pmatrix} a & b\\ c & d\\ \end{pmatrix} $, then determinant of matrix A is $ |A| = ad-bc$
# * Matrices represent transformation in space - scaling up and down, strecthing up and down.
# * Basically Det $|A|$ is an oriented multipilicative change in the volume under linear transformation, orientation is important because dets can have negative value. If Det is 2 then it doubles the volume, if it is 1/2 then it halves the volume.
# * If Det is zero its a destructive matrix, cannot be inverted. columns are linearly dependent, rows are linearly dependent
#
# ![scatter_plot_iris](../images/det_mat.png)
#
# **Inverse**
#
# * let A = $ \begin{pmatrix} a & b\\ c & d\\ \end{pmatrix} $ then inverse of matrix is $A ^-1 = \frac {1} {ad-bc} \begin{pmatrix} d & -b\\ -c & a \\ \end{pmatrix}  $
#
# * $90^o$ rotation of A
#
#
# ### Vectors
#
# **Vectors**
#
# A quantity having both direction and magnitude. Components of vectors are called scalars. Examples vectors force, acceleration, velocity.
# ![scatter_plot_iris](../images/vectors.png)
#
# **Scalars**
#
# A quantity having only magnitude but no direction, example - Time, distance, mass, area, speed, energy, power etc
#
# **Row Vector**
#
# $A = [a_1,a_2,a_3]$,
#
#
#
# **Column Vector**
#
# **Dot Product**
#
# **Unit Vector**
#
# **OrthoNormal Vector**
#
# **Vector Form of a plane**
#
# The dot product of the normal vector and a vector on the plane becomes the equation of the plane
#
# **Intersection of planes in 2d**
#
# ### Matrices + Vectors
#
# **Eigen Values/Eigen Vectors**
#
# ![scatter_plot_iris](../images/Eigenvectors.gif)
#
# * Singular Value Decompostion
# * Principal Components
# * Equations of lines/planes in Matrix notation
